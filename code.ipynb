# %%
import csv
import random
from faker import Faker
from datetime import datetime, timedelta


fake = Faker()


district_names = ['Thane', 'North Twenty Four Parganas', 'Bangalore', 'Pune', 'Mumbai Suburban',
    'South Twenty Four Parganas', 'Barddhaman', 'Ahmadabad', 'Murshidabad', 'Jaipur',
    'Nashik', 'Surat', 'Allahabad', 'Paschim Medinipur', 'Patna', 'Hugli', 'Rangareddy',
    'Nadia', 'East Godavari', 'Purba Champaran', 'Purba Medinipur', 'Guntur', 'Haora',
    'Muzaffarpur', 'Belgaum', 'Moradabad', 'Ghaziabad', 'Nagpur', 'Chennai', 'Azamgarh',
    'Lucknow', 'Kanpur Nagar', 'Ahmadnagar', 'Krishna', 'Kolkata', 'Jaunpur', 'Madhubani',
    'Sitapur', 'Bareilly', 'Gorakhpur', 'Agra', 'Gaya', 'Solapur', 'Visakhapatnam', 
    'Samastipur', 'Jalgaon', 'Chittoor', 'Vadodara', 'Muzaffarnagar', 'Malappuram', 'Hardoi',
    'Anantapur', 'Raipur', 'Kurnool', 'Mahbubnagar', 'Kheri', 'Kancheepuram', 'Maldah',
    'Saran', 'Hyderabad', 'Darbhanga', 'West Godavari', 'Vellore', 'Pashchim Champaran',
    'Kolhapur', 'Jalpaiguri', 'Rajkot', 'Sultanpur', 'Karimnagar', 'Thiruvallur', 'Aurangabad',
    'Jodhpur', 'Bijnor', 'Budaun', 'Varanasi', 'Alwar', 'Aligarh', 'North West', 'Ghazipur',
    'Bankura', 'Kushinagar', 'Ganjam', 'Warangal', 'Birbhum', 'Bulandshahar', 'Ludhiana', 
    'Vaishali', 'Nalgonda', 'Bahraich', 'Salem', 'Saharanpur', 'Viluppuram', 'Coimbatore', 
    'Meerut', 'Gonda', 'Sitamarhi', 'Rae Bareli', 'Prakasam', 'Nanded', 'Durg', 'Siwan',
    'Nagaur', 'Thiruvananthapuram', 'Ernakulam', 'Indore', 'Purnia', 'Barabanki', 'Ballia',
    'Pratapgarh', 'Thrissur', 'Banaskantha', 'Unnao', 'Deoria', 'Kozhikode', 'Mumbai',
    'Tirunelveli', 'Katihar', 'Udaipur', 'Madurai', 'Bhagalpur', 'Medak', 'Uttar Dinajpur',
    'Shahjahanpur', 'Satara', 'Mysore', 'Begusarai', 'Sri Potti Sriramulu Nellore', 'Rohtas',
    'Puruliya', 'Ranchi', 'Amravati', 'YSR', 'Bhavnagar', 'Nalanda', 'Nagaon', 'Sangli', 
    'Koch Bihar', 'Araria', 'Palakkad', 'Khammam', 'Yavatmal', 'Junagadh', 'Adilabad',
    'South', 'Bhojpur', 'Tiruchirappalli', 'Srikakulam', 'Maharajganj', 'Dhanbad', 'Tumkur', 
    'Sikar', 'Bilaspur', 'Kollam', 'Raigarh', 'Fatehpur', 'Cuttack', 'Cuddalore', 'Barmer',
    'Buldana', 'Bid', 'Ajmer', 'Gulbarga', 'Gopalganj', 'Siddharthnagar', 'Nizamabad',
    'Bharatpur', 'Mathura', 'West', 'Aurangabad', 'Kannur', 'Mayurbhanj', 'Firozabad',
    'Mirzapur', 'Amritsar', 'Tiruppur', 'Faizabad', 'Tiruvannamalai', 'Basti', 'Jabalpur',
    'Latur', 'Bellary', 'Giridih', 'Sabarkantha', 'Bhilwara', 'Thanjavur', 'Ambedkar Nagar',
    'Panchmahal']
gender_options = ['Woman', 'Man', 'Non-binary', 'Prefer not to say']
category_options = ['General', 'OBC', 'SC', 'ST']
education_options = ['Illiterate/ No formal Education', 'Primary', 'Secondary', 'Higher Secondary', 'Diploma/Associate degree', 'Under graduation', 'Post graduation', 'Other']
marital_status_options = ['Single/Unmarried', 'Married', 'Divorced/Separated', 'Widowed']
family_type_options = ['Nuclear', 'Joint']
residence_options = ['Rural', 'Urban', 'Slum']
migrant_options = ['Yes', 'No']
religious_options = ['Hindu', 'Islam', 'Christian', 'Sikh', 'Jain', 'Buddhist', 'Don\'t want to answer', 'Other']
job_options = ['Full-time', 'Part time', 'Not applicable']
delivery_hours_options = ['Less than 6 hours', '6-8 hours', '8-10 hours', '10-12 hours', 'More than 12 hours']
schedule_options = ['Daytime (6:00 AM - 6:00 PM)', 'Nighttime (6:00 PM - 6:00 AM)', 'Both', 'No fixed schedule']
delivery_schedule_options = ['Time-bound (with specific delivery deadlines)', 'Time-flexible (without specific delivery deadlines)', 'Both']
pay_structure_options = ['Fixed salary', 'Hourly wage', 'Per delivery rate', 'Distance based pay', 'Commission based pay', 'Guaranteed minimum earnings', 'Other']
transport_options = ['Walking', 'Bicycle', 'Electric bike', 'Scooters', 'Motorcycle', 'Car/Van']
scale_options = ['0 Never', '1 Rarely (once a month or less)', '2 Occasionally (2-3 times a month)', '3 Frequently (once a week or more)', '4 Always']
stress_scale_options = ['0-Never', '1-Rarely', '2-Sometimes', '3-Fairly often', '4-Very Often']
anxiety_scale_options = ['0-Not at all', '1-several days', '2-More than half the days', '3-Nearly every day']
frequency_options = ['0-Never', '1-Rarely (once a month or less)', '2-Occasionally (2-3 times a month)', '3-Frequently (once a week or more)', '4-Constantly']
traffic_options = ['0-Never', '1-Rarely', '2-Occasionally', '3-Frequently', '4-Always']
environmental_options = ['0-Never', '1-Rarely', '2-Occasionally', '3-Frequently', '4-Always']
safety_measures_options = ['Following traffic rules', 'Using a proper helmet and reflective gear at night', 'Planning routes to avoid unsafe areas', 'Taking breaks to avoid fatigue', 'None']
safety_gear_options = ['Helmet', 'Reflective vest', 'Face mask', 'Safety Training', 'Health insurance', 'Life insurance', 'Accidental Insurance', 'First aid kit', 'Raincoat/windbreaker', 'Sweater/Jacket', 'Sunglasses', 'Waterproof shoes', 'Elbow and Knee guard', 'Paid sick leaves']


def random_date(start_date, end_date):
    return start_date + timedelta(days=random.randint(0, (end_date - start_date).days))

start_date = datetime(2024, 8, 1)
end_date = datetime(2024, 9, 15)

def generate_respondent_data():
    respondent = {}
    
    respondent["Q1"] = "Agree"
    respondent["Q2"] = fake.name()
    respondent["Q3"] = "+91" + str(fake.random_number(digits=10, fix_len=True))
    respondent["Q4"] = fake.city()
    respondent["Q5"] = random.choice(district_names)
    respondent["Q6"] = random_date(start_date, end_date).strftime("%m/%d/%Y")
    respondent["Q7"] = random.randint(20, 60)
    respondent["Q8"] = random.choice(gender_options)
    respondent["Q9"] = random.choice(category_options)
    respondent["Q10"] = random.choice(education_options)
    respondent["Q11"] = random.choice(marital_status_options)
    respondent["Q12"] = random.choice(family_type_options)
    respondent["Q13"] = random.randint(0, 5)
    respondent["Q14"] = random.choice(residence_options)
    respondent["Q15"] = random.choice(["Yes", "No"])
    respondent["Q16"] = random.randint(100000, 1000000)
    respondent["Q17"] = random.choice(["Kutccha", "Semi-Kutccha", "Semi-pakka", "Pakka"])
    respondent["Q18"] = random.choice(migrant_options)
    respondent["Q19"] = random.choice(religious_options)
    respondent["Q20"] = random.choice(["Less than a year", "1 year", "1-2 years", "More than 2 years"])
    respondent["Q21"] = random.choice(job_options)
    respondent["Q22"] = random.choice(delivery_hours_options)
    respondent["Q23"] = random.randint(1, 7)
    respondent["Q24"] = random.choice(["Less than 10", "10 - 20", "20-30", "30-40", "40-50", "More than 50"])
    respondent["Q25"] = random.choice(["One platform", "Multiple platforms"])

    if respondent["Q25"] == "One platform":
        respondent["Q26"] = random.choice(platform_options)
    else:
        respondent["Q26"] = ", ".join(random.sample(platform_options, random.randint(2, 5)))

    respondent["Q27"] = random.choice(schedule_options)
    respondent["Q28"] = random.choice(delivery_schedule_options)
    respondent["Q29"] = ", ".join(random.sample(pay_structure_options, random.randint(1, 3)))
    respondent["Q30"] = random.choice(transport_options)
    respondent["Q31"] = random.choice(["Yes", "No"])
    respondent["Q32"] = random.randint(10000, 60000)

    for i in range(33, 34):
        for subq in ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']:
            respondent[f"Q{i}{subq}"] = random.choice(scale_options)

    for i in range(34, 35):
        for subq in ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']:
            respondent[f"Q{i}{subq}"] = random.choice(stress_scale_options)

    for i in range(35, 36):
        for subq in ['a', 'b', 'c', 'd', 'e', 'f', 'g']:
            respondent[f"Q{i}{subq}"] = random.choice(anxiety_scale_options)

    for i in range(36, 37):
        for subq in ['a', 'b', 'c', 'd', 'e']:
            respondent[f"Q{i}{subq}"] = random.choice(frequency_options)

    for i in range(49, 50):
        for subq in ['a', 'b', 'c', 'd', 'e', 'f']:
            respondent[f"Q{i}{subq}"] = random.choice(traffic_options)

    for i in range(50, 51):
        for subq in ['a', 'b', 'c', 'd', 'e', 'f', 'g']:
            respondent[f"Q{i}{subq}"] = random.choice(environmental_options)

    respondent["Q51"] = random.choice(["Smoking", "Alcoholism", "Chewing Tobacco", "Any other Psychotropic substances", "None"])
    respondent["Q52"] = ", ".join(random.sample(safety_measures_options, random.randint(1, 4)))

    for i in range(53, 54):
        for subq in ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm', 'n']:
            respondent[f"Q{i}{subq}"] = random.choice(["Yes", "No"])

    respondent["Q54"] = random.choice(["Yes", "No"])
    respondent["Q55"] = random.choice(["Not helpful at all", "Somewhat helpful", "Neither helpful nor unhelpful", "Somewhat unhelpful", "Very helpful"])
    respondent["Q56"] = random.choice(["Yes", "No"])
    return respondent

data = [generate_respondent_data() for _ in range(500)]

df = pd.DataFrame(data)
df.to_csv('responses.csv', index=False)
